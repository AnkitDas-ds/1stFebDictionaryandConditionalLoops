# %%
d={} #this creates an empty dictionary

# %%
type(d) #KEY should always be unique in dictionary
# Out:
# dict

# %%
d1={'key':"sudh"}

# %%
d1
# Out:
# {'key': 'sudh'}

# %%
d2={'name':"sudhanshu",'email':"ss@gmail.com",'number':6290362403}

# %%
d2
# Out:
# {'name': 'sudhanshu', 'email': 'ss@gmail.com', 'number': 6290362403}

# %%
d3={234:"sudh",_wer:"kumar"} #not allowed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 d3={234:"sudh",_wer:"kumar"}
#
# NameError: name '_wer' is not defined

# %%
d3={234:"sudh","_wer":"kumar",True:24234} #no problems

# %%
d3[234]
# Out:
# 'sudh'

# %%
d3["_wer"]
# Out:
# 'kumar'

# %%
d3[True]
# Out:
# 24234

# %%
d3[1] #this is because internally True is 1 so True-1 so d3[1]=d3[True]=24234
# Out:
# 24234

# %%
d4={'name':"sudh",'mail_id':"ss@gmail.com",'name':"sudhanshu"}

# %%
d4['name'] #since name is repeated twice the latest key value pair is overwritten and the last value of key name is sudhanshu
# Out:
# 'sudhanshu'

# %%
d5={"company":"pwskills","courses":["webdev","datascience","java with system design"]}

# %%
d5
# Out:
# {'company': 'pwskills',
#  'courses': ['webdev', 'datascience', 'java with system design']}

# %%
d5["courses"]
# Out:
# ['webdev', 'datascience', 'java with system design']

# %%
d5["courses"][2]
# Out:
# 'java with system design'

# %%
d5["courses"][1]
# Out:
# 'datascience'

# %%
d6={"number":[2,34,3,34,34],"assignment":(1,2,3,4,5,6),"launch date":{28,14,14},"class time":{"web dev":8,"data science":8,"java with system design":7}}

# %%
d6 #we can have anything as a value
# Out:
# {'number': [2, 34, 3, 34, 34],
#  'assignment': (1, 2, 3, 4, 5, 6),
#  'launch date': {14, 28},
#  'class time': {'web dev': 8, 'data science': 8, 'java with system design': 7}}

# %%
d6["class time"]
# Out:
# {'web dev': 8, 'data science': 8, 'java with system design': 7}

# %%
d6["class time"]["java with system design"] #damnnn
# Out:
# 7

# %%
d6["mentor"]=["sudhanshu","krish","anurag","hayder"]

# %%
d6 #if the key is available then the value of that key will be updated
# Out:
# {'number': [2, 34, 3, 34, 34],
#  'assignment': (1, 2, 3, 4, 5, 6),
#  'launch date': {14, 28},
#  'class time': {'web dev': 8, 'data science': 8, 'java with system design': 7},
#  'mentor': ['sudhanshu', 'krish', 'anurag', 'hayder']}

# %%
del d6["number"]

# %%
 d6 # number and its value have been deleted
# Out:
# {'assignment': (1, 2, 3, 4, 5, 6),
#  'launch date': {14, 28},
#  'class time': {'web dev': 8, 'data science': 8, 'java with system design': 7},
#  'mentor': ['sudhanshu', 'krish', 'anurag', 'hayder']}

# %%
d6.keys()
# Out:
# dict_keys(['assignment', 'launch date', 'class time', 'mentor'])

# %%
list(d6.keys())
# Out:
# ['assignment', 'launch date', 'class time', 'mentor']

# %%
d6.values()
# Out:
# dict_values([(1, 2, 3, 4, 5, 6), {28, 14}, {'web dev': 8, 'data science': 8, 'java with system design': 7}, ['sudhanshu', 'krish', 'anurag', 'hayder']])

# %%
list(d6.values())
# Out:
# [(1, 2, 3, 4, 5, 6),
#  {14, 28},
#  {'web dev': 8, 'data science': 8, 'java with system design': 7},
#  ['sudhanshu', 'krish', 'anurag', 'hayder']]

# %%
d6.items()
# Out:
# dict_items([('assignment', (1, 2, 3, 4, 5, 6)), ('launch date', {28, 14}), ('class time', {'web dev': 8, 'data science': 8, 'java with system design': 7}), ('mentor', ['sudhanshu', 'krish', 'anurag', 'hayder'])])

# %%
list(d6.items())
# Out:
# [('assignment', (1, 2, 3, 4, 5, 6)),
#  ('launch date', {14, 28}),
#  ('class time',
#   {'web dev': 8, 'data science': 8, 'java with system design': 7}),
#  ('mentor', ['sudhanshu', 'krish', 'anurag', 'hayder'])]

# %%
d6.pop() # not possible pop in case of dictionary needs atleast 1 argument inside it
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 d6.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
#CONTROL FLOW

# %%
if marks >= 80:
    print("You will be a part of A0 batch")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 if marks >= 80:
#       2     print("You will be a part of A0 batch")
#
# NameError: name 'marks' is not defined

# %%
#indentation is important in python

# %%
marks = 10
if marks>=80:
    print("You will be a part of A0 batch")
elif marks >=60 and marks <=80:
    print("You will be a part of A1 batch")
elif marks >=40 and marks <=60:
    print("You will be a part of A2 batch")
else:
    print("You will be a part of A3 batch")
# Out:
# You will be a part of A3 batch

# %%
10>=80  # remember the and gate table
# Out:
# False

# %%
marks = int(input("Enter your marks"))
if marks>=80:
    print("You will be a part of A0 batch")
elif marks >=60 and marks <=80:
    print("You will be a part of A1 batch")
elif marks >=40 and marks <=60:
    print("You will be a part of A2 batch")
else:
    print("You will be a part of A3 batch")
# Out:
# Enter your marks45
# You will be a part of A2 batch

# %%
marks = float(input("Enter your marks"))
# Out:
# Enter your marks45

# %%
type(marks)
# Out:
# float

# %%
price=int(input("Enter the price"))
if price >1000:
    print("i will not purchase")
else:
    print("i will purchase")
# Out:
# Enter the price 500
# i will purchase

# %%
price=int(input("Enter the price"))
if price >1000:
    print("i will not purchase")
# Out:
# Enter the price1000

# %%
price=int(input("Enter the price")) # nested if else
if price >1000:
    print("i will not purchase")
    if price>5000:
        print("this is too much")
    elif price<2000:
        print("its okay kind of price")
elif price<1000:
    print("i will purchase")
else:
    print("not interested")
# Out:
# Enter the price1000
# not interested

# %%
l=[1,2,3,3,4,5,6,7,8]

# %%
l[0]+1
# Out:
# 2

# %%
l1=[]

# %%
l1.append(l[0]+1)

# %%
l1
# Out:
# [2]

# %%
l
# Out:
# [1, 2, 3, 3, 4, 5, 6, 7, 8]

# %%
for i in l :
    print(i)
# Out:
# 1
# 2
# 3
# 3
# 4
# 5
# 6
# 7
# 8

# %%
for i in l :
    print(i+1)
# Out:
# 2
# 3
# 4
# 4
# 5
# 6
# 7
# 8
# 9

# %%
for i in l : # for every element in l you are printing the entire list
    print(l)
# Out:
# [1, 2, 3, 3, 4, 5, 6, 7, 8]
# [1, 2, 3, 3, 4, 5, 6, 7, 8]
# [1, 2, 3, 3, 4, 5, 6, 7, 8]
# [1, 2, 3, 3, 4, 5, 6, 7, 8]
# [1, 2, 3, 3, 4, 5, 6, 7, 8]
# [1, 2, 3, 3, 4, 5, 6, 7, 8]
# [1, 2, 3, 3, 4, 5, 6, 7, 8]
# [1, 2, 3, 3, 4, 5, 6, 7, 8]
# [1, 2, 3, 3, 4, 5, 6, 7, 8]

# %%
l1=[]
for i in l :
    print(i+1)
    l1.append(i+1)
# Out:
# 2
# 3
# 4
# 4
# 5
# 6
# 7
# 8
# 9

# %%
l1
# Out:
# [2, 3, 4, 4, 5, 6, 7, 8, 9]

# %%
l
# Out:
# [1, 2, 3, 3, 4, 5, 6, 7, 8]

# %%
l=["sudh","kumar","pwskills","course"]

# %%
l2=[]
for i in l:
    print(i)
    l2.append(i.upper())
# Out:
# sudh
# kumar
# pwskills
# course

# %%
l2
# Out:
# ['SUDH', 'KUMAR', 'PWSKILLS', 'COURSE']

# %%
l=[1,2,3,4,5,"sudh","kumar",324,34.456,"abc"]

# %%
l1_num=[]
l2_str=[]
for i in l:
    if type(i) == int or type(i) == float :
        l1_num.append(i)
    else:
        l2_str.append(i)

# %%
l1_num
# Out:
# [1, 2, 3, 4, 5, 324, 34.456]

# %%
l2_str
# Out:
# ['sudh', 'kumar', 'abc']

# %%
# next day we will start for loop

# %%
# []- list
# ()-tuple
# {}-with flat element set 
# {}-with key value pair

# %%
t=(True)

# %%
len(t) #important
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 len(t)
#
# TypeError: object of type 'bool' has no len()

# %%
t=(True,False)

# %%
len(T)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 len(T)
#
# NameError: name 'T' is not defined

# %%
len(t)
# Out:
# 2

# %%
t.count(True)
# Out:
# 1

# %%
s2=(1,4,7,6.6,True)

# %%
s2.count(True)# here 1 will also be considered as True that is why count True is shown as 2 here as 1=True here
# Out:
# 2
